# %%
import datetime

def getdate():
    return datetime.datetime.now()

x = int(input("Press the number you have to following name:\n(1) For Rushi\n(2) For Ritzz\n(3) For Nick\n"))

l = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

if x == 1:
    s = input("What do you want Rushi food list or exercise list??\n")
    if s.capitalize() == "Food":
        y = input("What do you want to write or read??\n")
        if y.capitalize() == "Write":
            print("[", getdate(), "]")
            with open("Rushi_food.txt", "a") as f:
                print("What did you eat:")
                d = input()
                f.write(f"\n{d}  {l}")
            print("You have successfully entered.")
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        elif y.capitalize() == "Read":
            print("[", getdate(), "]")
            with open("Rushi_food.txt") as f:
                r = f.read()
                print(r)
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        else:
            print("Invalid input, please try again.")
    elif s.capitalize() == "Exercise":
        z = input("What do you want to write or read??\n")
        if z.capitalize() == "Write":
            print("[", getdate(), "]")
            with open("Rushi_exercise.txt", "a") as f:
                d = input("What did you do today:")
                f.write(f"\n{d}  {l}")
            print("You have successfully entered.")
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        elif z.capitalize() == "Read":
            print("[", getdate(), "]")
            with open("Rushi_exercise.txt") as f:
                r = f.read()
                print(r)
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        else:
            print("Invalid input, please try again.")
    else:
        print("Invalid input, please try again.")

elif x == 2:
    s = input("What do you want Ritzz food list or exercise list??\n")
    if s.capitalize() == "Food":
        y = input("What do you want to write or read??\n")
        if y.capitalize() == "Write":
            print("[", getdate(), "]")
            with open("Ritzz_food.txt", "a") as f:
                print("What did you eat:")
                d = input()
                f.write(f"\n{d}  {l}")
            print("You have successfully entered.")
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        elif y.capitalize() == "Read":
            print("[", getdate(), "]")
            with open("Ritzz_food.txt") as f:
                r = f.read()
                print(r)
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        else:
            print("Invalid input, please try again.")
    elif s.capitalize() == "Exercise":
        z = input("What do you want to write or read??\n")
        if z.capitalize() == "Write":
            print("[", getdate(), "]")
            with open("Ritzz_exercise.txt", "a") as f:
                d = input("What did you do today:")
                f.write(f"\n{d}  {l}")
            print("You have successfully entered.")
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        elif z.capitalize() == "Read":
            print("[", getdate(), "]")
            with open("Ritzz_exercise.txt") as f:
                r = f.read()
                print(r)
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        else:
            print("Invalid input, please try again.")
    else:
        print("Invalid input, please try again.")

elif x == 3:
    s = input("What do you want Nick food list or exercise list??\n")
    if s.capitalize() == "Food":
        y = input("What do you want to write or read??\n")
        if y.capitalize() == "Write":
            print("[", getdate(), "]")
            with open("Nick_food.txt", "a") as f:
                print("What did you eat:")
                d = input()
                f.write(f"\n{d}  {l}")
            print("You have successfully entered.")
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        elif y.capitalize() == "Read":
            print("[", getdate(), "]")
            with open("Nick_food.txt") as f:
                r = f.read()
                print(r)
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        else:
            print("Invalid input, please try again.")
    elif s.capitalize() == "Exercise":
        z = input("What do you want to write or read??\n")
        if z.capitalize() == "Write":
            print("[", getdate(), "]")
            with open("Nick_exercise.txt", "a") as f:
                d = input("What did you do today:")
                f.write(f"\n{d}  {l}")
            print("You have successfully entered.")
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        elif z.capitalize() == "Read":
            print("[", getdate(), "]")
            with open("Nick_exercise.txt") as f:
                r = f.read()
                print(r)
            print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        else:
            print("Invalid input, please try again.")
    else:
        print("Invalid input, please try again.")

else:
    print("Invalid input, Please press the correct number.")

print("THANKS FOR USING:\nBY@Omkar")
